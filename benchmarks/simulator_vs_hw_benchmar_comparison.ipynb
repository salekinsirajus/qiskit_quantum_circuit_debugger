# %%
sm_result = [
    {'00': 251, '10': 227, '11': 257, '01': 265},
    {'01': 242, '11': 256, '10': 254, '00': 248},
    {'11': 1000},
    {'11': 1000},
]

# %%
hw_result = [
    {'00': 241, '01': 251, '10': 244, '11': 264},
    {'00': 236, '01': 262, '10': 258, '11': 244},
    {'00': 2, '01': 17, '10': 43, '11': 938},
    {'00': 7, '01': 27, '10': 30, '11': 936},
]

# %%
from qiskit.visualization import plot_histogram

# %%
data =[sm_result[0], hw_result[0]]
legend = ["simulator_bp1", "hardware_bp1"]
plot_histogram(data, legend=legend, figsize=(10,8))

# %%
data =[sm_result[1], hw_result[1]]
legend = ["simulator_bp2", "hardware_bp2"]
plot_histogram(data, legend=legend, figsize=(10,8))

# %%
data =[sm_result[2], hw_result[2]]
legend = ["simulator_bp3", "hardware_bp3"]
plot_histogram(data, legend=legend, figsize=(10,8))

# %%
data =[sm_result[3], hw_result[3]]
legend = ["simulator_w/o_debugger", "hardware_w/o_debugger"]
plot_histogram(data, legend=legend, figsize=(10,8))

# %%
data =[sm_result[3], hw_result[2]]
legend = ["simulator_w/o_debugger", "hardware_w_debugger"]
plot_histogram(data, legend=legend, figsize=(10,8))
